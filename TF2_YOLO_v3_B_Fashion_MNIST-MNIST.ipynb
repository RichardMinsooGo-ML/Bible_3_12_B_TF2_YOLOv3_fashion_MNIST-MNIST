# %% [markdown]
# # 1. Check GPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Oct 21 22:05:31 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # 2. Git Clone to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_12_B_TF2_YOLOv3_fashion_MNIST-MNIST.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 41 (delta 11), reused 19 (delta 1), pack-reused 0
# Unpacking objects: 100% (41/41), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_12_B_TF2_YOLOv3_fashion_MNIST-MNIST
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %% [markdown]
# # 3. Output window clear
#
# In general, in the case of Classification or Object Detection, the number of files is usually larger than the number that can be displayed in Colab. In this case, it may be necessary to arrange the display screen.

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. Download datasets
#
# If data in another person's (ex. author's) Google Drive is shared, it can be downloaded using gdown . If the shared data is visited and downloaded one by one, the data structure may be distorted, so it is recommended to configure the code using gdown if possible.

# %%
# !pip install --upgrade --no-cache-dir gdown

# Mini-COCO dataset download from Auther's Github repository
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '1kcziuTBjQsBkrIdvB7GwB6FXHHYad1Im'
output_name = 'fashion_mnist.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1kcziuTBjQsBkrIdvB7GwB6FXHHYad1Im/view?usp=sharing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.5.3-py3-none-any.whl size=14841 sha256=37836228d12914279390268592bba312fb6ebc95a8ed205cd500f24513a38521
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uwh8ix2w/wheels/94/8d/0b/bdcd83555c3555f91a33f6c2384428d9f163c7d75ab0d272b4
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1kcziuTBjQsBkrIdvB7GwB6FXHHYad1Im
# To: /content/fashion_mnist.zip
# 100%|██████████| 115M/115M [00:00<00:00, 132MB/s]
# 'fashion_mnist.zip'

# %%
! unzip /content/fashion_mnist.zip -d /content/dataset
clear_output()
! rm /content/fashion_mnist.zip

# %% [markdown]
# # 5. Check RAM size
#
# If the size of the dataset to be processed is large, the RAM provided by Colab may be insufficient. In this case, you can select a large RAM and use it to check the size of the RAM.

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import shutil
shutil.rmtree("sample_data")

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 6. Download Darknet Weights

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights
# Out:
# --2022-10-21 22:07:07--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  26.5MB/s    in 1.3s
#
# 2022-10-21 22:07:08 (26.5 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-10-21 22:07:08--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  39.7MB/s    in 6.4s
#
# ...

# %%
import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/tmp")
# shutil.move("/content/yolov4.weights", "/content/tmp")
# Out:
# '/content/checkpoints/yolov3.weights'

# %%
# !pip install terminaltables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 7. Download MNIST YOLOv3 Pre-trained Weight

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1zo1BtNoflnwbCafG5r1WBZ6LJgwnSw_3'
output_name = 'YOLO_v3_trained_weight_fashion_mnist.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1zo1BtNoflnwbCafG5r1WBZ6LJgwnSw_3/view?usp=sharing

! unzip /content/YOLO_v3_trained_weight_fashion_mnist.zip -d /content/checkpoints
clear_output()
! rm /content/YOLO_v3_trained_weight_fashion_mnist.zip

# %% [markdown]
# # 8. Train YoloV3 from Pretrained Weight
# Use default configuration file.
#
# Please check `TRAIN_FROM_CHECKPOINT` and `TRAIN_YOLO_TINY` at `./configuration.py`.
# ```
# TRAIN_FROM_CHECKPOINT       = True
# TRAIN_YOLO_TINY             = False
# ```

# %%
# !python train.py
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5025991071517751322
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5668616939810295918
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# train length : 4096
#          -------------------  Model Loaded! -------------------
#
# 100% 256/256 [07:12<00:00,  1.69s/it]
# Train Loss // giou:   3.88, conf:   1.35, prob:   5.90, total:  11.13
# 100% 256/256 [07:02<00:00,  1.65s/it]
# Train Loss // giou:   1.99, conf:   0.27, prob:   3.45, total:   5.72
# 100% 256/256 [07:00<00:00,  1.64s/it]
# Train Loss // giou:   1.88, conf:   0.24, prob:   3.11, total:   5.23
# 100% 256/256 [06:59<00:00,  1.64s/it]
# ...

# %%
# !python evaluate_mAP.py
# Out:
# 2022-10-21 08:13:36.545437: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# test length : 1024
#
# calculating mAP50...
#
# ...
# 1/1 [==============================] - 0s 473ms/step
# 100% 1024/1024 [08:22<00:00,  2.04it/s]
# 98.770% = 0 AP
# 98.458% = 1 AP
# 97.584% = 2 AP
# 98.677% = 3 AP
# 98.258% = 4 AP
# 93.997% = 5 AP
# 98.005% = 6 AP
# 97.936% = 7 AP
# 98.195% = 8 AP
# 97.213% = 9 AP
# 96.021% = Ankle_boot AP
# 98.868% = Bag AP
# 81.967% = Coat AP
# 89.355% = Dress AP
# 88.201% = Pullover AP
# 97.748% = Sandal AP
# 69.086% = Shirt AP
# 95.652% = Sneaker AP
# 83.482% = T-shirt_top AP
# 96.509% = Trouser AP
# mAP = 93.699%, 2.07 FPS

# %% [markdown]
# # 9. Train YoloV3 from Darknet Weight
#
# Please change `TRAIN_FROM_CHECKPOINT = False` and `TRAIN_YOLO_TINY` at `./configuration.py`.
# ```
# TRAIN_FROM_CHECKPOINT       = False
# TRAIN_YOLO_TINY             = False
# ```

# %%
# !python train.py
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11419327813293115952
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5925226899198014436
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# train length : 4096
# skipping conv2d_74
# skipping conv2d_66
# skipping conv2d_58
# 100% 256/256 [06:52<00:00,  1.61s/it]
# Train Loss // giou:  11.08, conf: 543.42, prob: 102.59, total: 657.09
# 100% 256/256 [06:59<00:00,  1.64s/it]
# Train Loss // giou:   7.00, conf:  40.46, prob:  37.46, total:  84.92
# 100% 256/256 [07:00<00:00,  1.64s/it]
# Train Loss // giou:   5.74, conf:  16.78, prob:  19.73, total:  42.25
# 100% 256/256 [06:59<00:00,  1.64s/it]
# ...

# %%
# !python evaluate_mAP.py
# Out:
# 2022-10-21 08:50:57.518289: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# test length : 1024
#
# calculating mAP50...
#
# ...
# 1/1 [==============================] - 0s 431ms/step
# 100% 1024/1024 [08:25<00:00,  2.02it/s]
# 96.647% = 0 AP
# 97.058% = 1 AP
# 93.818% = 2 AP
# 91.844% = 3 AP
# 94.447% = 4 AP
# 82.779% = 5 AP
# 94.727% = 6 AP
# 95.525% = 7 AP
# 89.535% = 8 AP
# 92.578% = 9 AP
# 88.456% = Ankle_boot AP
# 94.605% = Bag AP
# 70.063% = Coat AP
# 79.954% = Dress AP
# 78.433% = Pullover AP
# 92.883% = Sandal AP
# 39.221% = Shirt AP
# 93.336% = Sneaker AP
# 79.572% = T-shirt_top AP
# 96.435% = Trouser AP
# mAP = 87.096%, 2.15 FPS

# %% [markdown]
# # 10. Train YoloV3-tiny from Pretrained Weight
#
# Please change `TRAIN_FROM_CHECKPOINT = True` and `TRAIN_YOLO_TINY = True` at `./configuration.py`.
# ```
# TRAIN_FROM_CHECKPOINT       = True
# TRAIN_YOLO_TINY             = True
# ```

# %% [markdown]
# Download Pretrained weights from Auther's Google Drive.

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1pZaxKB6_1eFls49jThfJ2ZfHAEoIXsqI'
output_name = 'yolo_v3_fashion_mnist_tiny.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1pZaxKB6_1eFls49jThfJ2ZfHAEoIXsqI/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pZaxKB6_1eFls49jThfJ2ZfHAEoIXsqI
# To: /content/yolo_v3_fashion_mnist_tiny.zip
# 100%|██████████| 32.4M/32.4M [00:00<00:00, 49.9MB/s]
# 'yolo_v3_fashion_mnist_tiny.zip'

# %%
! unzip /content/yolo_v3_fashion_mnist_tiny.zip -d /content/checkpoints
clear_output()
! rm /content/yolo_v3_fashion_mnist_tiny.zip

# %%
# !python train.py
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6086276828017908357
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 441781451118339007
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# train length : 4096
#          -------------------  Model Loaded! -------------------
#
# 100% 256/256 [03:01<00:00,  1.41it/s]
# Train Loss // giou:   5.19, conf:   1.54, prob:  10.25, total:  16.97
# 100% 256/256 [02:57<00:00,  1.44it/s]
# Train Loss // giou:   2.95, conf:   0.63, prob:   8.31, total:  11.88
# 100% 256/256 [02:57<00:00,  1.44it/s]
# Train Loss // giou:   2.78, conf:   0.58, prob:   7.71, total:  11.07
# 100% 256/256 [02:57<00:00,  1.44it/s]
# ...

# %%
# !python evaluate_mAP.py
# Out:
# 2022-10-21 23:31:46.619019: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# test length : 1024
#
# calculating mAP50...
#
# ...
# 1/1 [==============================] - 0s 88ms/step
# 100% 1024/1024 [02:04<00:00,  8.24it/s]
# 96.944% = 0 AP
# 96.851% = 1 AP
# 89.888% = 2 AP
# 88.316% = 3 AP
# 94.331% = 4 AP
# 84.496% = 5 AP
# 94.076% = 6 AP
# 92.167% = 7 AP
# 93.398% = 8 AP
# 91.119% = 9 AP
# 91.671% = Ankle_boot AP
# 95.595% = Bag AP
# 61.289% = Coat AP
# 78.598% = Dress AP
# 79.054% = Pullover AP
# 93.336% = Sandal AP
# 46.186% = Shirt AP
# 87.065% = Sneaker AP
# 73.579% = T-shirt_top AP
# 94.527% = Trouser AP
# mAP = 86.124%, 8.67 FPS

# %% [markdown]
# # 11. Train YoloV3-tiny from Darknet Weight
#
# Please change `TRAIN_FROM_CHECKPOINT = False` and `TRAIN_YOLO_TINY = True` at `./configuration.py`.
# ```
# TRAIN_FROM_CHECKPOINT       = False
# TRAIN_YOLO_TINY             = True
# ```

# %%
# !python train.py
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7028784541491873087
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 794608356446969263
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# train length : 4096
# skipping conv2d_12
# skipping conv2d_9
# 100% 256/256 [03:02<00:00,  1.40it/s]
# Train Loss // giou:   9.12, conf: 159.18, prob:  74.15, total: 242.44
# 100% 256/256 [02:58<00:00,  1.44it/s]
# Train Loss // giou:   5.11, conf:  16.82, prob:  35.23, total:  57.16
# 100% 256/256 [02:56<00:00,  1.45it/s]
# Train Loss // giou:   4.36, conf:   7.81, prob:  24.83, total:  37.01
# 100% 256/256 [02:56<00:00,  1.45it/s]
# ...

# %%
# !python evaluate_mAP.py
# Out:
# 2022-10-21 23:52:58.124835: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# test length : 1024
#
# calculating mAP50...
#
# ...
# 1/1 [==============================] - 0s 91ms/step
# 100% 1024/1024 [03:13<00:00,  5.28it/s]
# 81.561% = 0 AP
# 89.924% = 1 AP
# 52.278% = 2 AP
# 61.713% = 3 AP
# 77.339% = 4 AP
# 41.364% = 5 AP
# 79.516% = 6 AP
# 70.683% = 7 AP
# 70.581% = 8 AP
# 65.995% = 9 AP
# 68.996% = Ankle_boot AP
# 79.972% = Bag AP
# 39.404% = Coat AP
# 47.111% = Dress AP
# 54.032% = Pullover AP
# 58.923% = Sandal AP
# 19.630% = Shirt AP
# 75.707% = Sneaker AP
# 52.642% = T-shirt_top AP
# 88.229% = Trouser AP
# mAP = 63.780%, 8.74 FPS
